# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 717

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
    
    # Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
     # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
     # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_wdescription = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_wdescription,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
                          

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 15 | east london
# Processing Record 2 of Set 15 | geraldton
# Processing Record 3 of Set 15 | biak
# Processing Record 4 of Set 15 | vaini
# Processing Record 5 of Set 15 | murray bridge
# Processing Record 6 of Set 15 | longyearbyen
# Processing Record 7 of Set 15 | rikitea
# Processing Record 8 of Set 15 | taltal
# Processing Record 9 of Set 15 | yantzaza
# Processing Record 10 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 15 | sioux lookout
# Processing Record 12 of Set 15 | faanui
# Processing Record 13 of Set 15 | port lincoln
# Processing Record 14 of Set 15 | armizonskoye
# Processing Record 15 of Set 15 | touros
# Processing Record 16 of Set 15 | qaanaaq
# Processing Record 17 of Set 15 | kahului
# Processing Record 18 of Set 15 | cidreira
# Processing Record 19 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 15 | prince george
# Processing Record 21 of Set 15 | saint george
# Processing Record 22 of Set 15 | gera
# Processing Record 23 of Set 15 | korla
# Processing Record 24 of Set 15 | butaritari
# Processing Record 25 of Set 15 | punta arenas
# Processing Record 26 of Set 15 | albany
# Processing Record 27 of Set 15 | pevek
# Processing Record 28 of Set 15 | new norfolk
# Processing Record 29 of Set 15 | cardston
# Processing Record 30 of Set 15 | brenes
# Processing Record 31 of Set 15 | olafsvik
# Processing Record 32 of Set 15 | subaytilah
# City not found. Skipping...
# Processing Record 33 of Set 15 | kaitangata
# Processing Record 34 of Set 15 | karratha
# Processing Record 35 of Set 15 | beroroha
# Processing Record 36 of Set 15 | arraial do cabo
# Processing Record 37 of Set 15 | belmonte
# Processing Record 38 of Set 15 | puerto ayora
# Processing Record 39 of Set 15 | barrow
# Processing Record 40 of Set 15 | tazovskiy
# Processing Record 41 of Set 15 | anadyr
# Processing Record 42 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 15 | goderich
# Processing Record 44 of Set 15 | lakeland highlands
# Processing Record 45 of Set 15 | saint-georges
# Processing Record 46 of Set 15 | ust-omchug
# Processing Record 47 of Set 15 | molina
# Processing Record 48 of Set 15 | codrington
# Processing Record 49 of Set 15 | hihifo
# City not found. Skipping...
# Processing Record 50 of Set 15 | namatanai
# Processing Record 1 of Set 16 | ribeira grande
# Processing Record 2 of Set 16 | clyde river
# Processing Record 3 of Set 16 | saint-philippe
# Processing Record 4 of Set 16 | sucua
# Processing Record 5 of Set 16 | solnechnyy
# Processing Record 6 of Set 16 | kapaa
# Processing Record 7 of Set 16 | mataura
# Processing Record 8 of Set 16 | ventsy
# Processing Record 9 of Set 16 | hobart
# Processing Record 10 of Set 16 | cape town
# Processing Record 11 of Set 16 | bathsheba
# Processing Record 12 of Set 16 | maneadero
# Processing Record 13 of Set 16 | ushuaia
# Processing Record 14 of Set 16 | samarai
# Processing Record 15 of Set 16 | chumikan
# Processing Record 16 of Set 16 | guerrero negro
# Processing Record 17 of Set 16 | kavieng
# Processing Record 18 of Set 16 | norman wells
# Processing Record 19 of Set 16 | praia da vitoria
# Processing Record 20 of Set 16 | castro
# Processing Record 21 of Set 16 | krasnoselkup
# Processing Record 22 of Set 16 | mar del plata
# Processing Record 23 of Set 16 | hermanus
# Processing Record 24 of Set 16 | dikson
# Processing Record 25 of Set 16 | male
# Processing Record 26 of Set 16 | jamestown
# Processing Record 27 of Set 16 | eureka
# Processing Record 28 of Set 16 | half moon bay
# Processing Record 29 of Set 16 | nova olimpia
# Processing Record 30 of Set 16 | ilulissat
# Processing Record 31 of Set 16 | asau
# Processing Record 32 of Set 16 | lethem
# Processing Record 33 of Set 16 | nikolskoye
# Processing Record 34 of Set 16 | kavaratti
# Processing Record 35 of Set 16 | poso
# Processing Record 36 of Set 16 | provideniya
# Processing Record 37 of Set 16 | colomiers
# Processing Record 38 of Set 16 | podosinovets
# Processing Record 39 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 16 | maracacume
# Processing Record 41 of Set 16 | toliary
# City not found. Skipping...
# Processing Record 42 of Set 16 | lebu
# Processing Record 43 of Set 16 | lubango
# Processing Record 44 of Set 16 | gangotri
# City not found. Skipping...
# Processing Record 45 of Set 16 | atuona
# Processing Record 46 of Set 16 | kodiak
# Processing Record 47 of Set 16 | leshukonskoye
# Processing Record 48 of Set 16 | reyes
# Processing Record 49 of Set 16 | upernavik
# Processing Record 50 of Set 16 | bredasdorp
# Processing Record 1 of Set 17 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 17 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 17 | tuktoyaktuk
# Processing Record 4 of Set 17 | yellowknife
# Processing Record 5 of Set 17 | lompoc
# Processing Record 6 of Set 17 | laguna
# Processing Record 7 of Set 17 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 17 | khatanga
# Processing Record 9 of Set 17 | komsomolskiy
# Processing Record 10 of Set 17 | bethel
# Processing Record 11 of Set 17 | merauke
# Processing Record 12 of Set 17 | rabo de peixe
# Processing Record 13 of Set 17 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 17 | hasaki
# Processing Record 15 of Set 17 | mahebourg
# Processing Record 16 of Set 17 | imbituba
# Processing Record 17 of Set 17 | tilichiki
# Processing Record 18 of Set 17 | tasiilaq
# Processing Record 19 of Set 17 | maceio
# Processing Record 20 of Set 17 | busselton
# Processing Record 21 of Set 17 | haines junction
# Processing Record 22 of Set 17 | hilo
# Processing Record 23 of Set 17 | tabas
# Processing Record 24 of Set 17 | oussouye
# Processing Record 25 of Set 17 | yeppoon
# Processing Record 26 of Set 17 | sao joao da barra
# Processing Record 27 of Set 17 | cherskiy
# Processing Record 28 of Set 17 | hithadhoo
# Processing Record 29 of Set 17 | banda aceh
# Processing Record 30 of Set 17 | bluff
# Processing Record 31 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 17 | klaksvik
# Processing Record 33 of Set 17 | homer
# Processing Record 34 of Set 17 | japura
# Processing Record 35 of Set 17 | iqaluit
# Processing Record 36 of Set 17 | padang
# Processing Record 37 of Set 17 | igrim
# Processing Record 38 of Set 17 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 17 | saldanha
# Processing Record 40 of Set 17 | hambantota
# Processing Record 41 of Set 17 | biltine
# Processing Record 42 of Set 17 | berlevag
# Processing Record 43 of Set 17 | le moule
# Processing Record 44 of Set 17 | ulaangom
# Processing Record 45 of Set 17 | caravelas
# Processing Record 46 of Set 17 | pushkino
# Processing Record 47 of Set 17 | akot
# Processing Record 48 of Set 17 | coihaique
# Processing Record 49 of Set 17 | alice springs
# Processing Record 50 of Set 17 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 18 | luderitz
# Processing Record 2 of Set 18 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 18 | pacific grove
# Processing Record 4 of Set 18 | el jicaro
# Processing Record 5 of Set 18 | navolato
# Processing Record 6 of Set 18 | domoni
# Processing Record 7 of Set 18 | carnarvon
# Processing Record 8 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 18 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 18 | ahipara
# Processing Record 11 of Set 18 | airai
# Processing Record 12 of Set 18 | leningradskiy
# Processing Record 13 of Set 18 | yeghegnut
# Processing Record 14 of Set 18 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 18 | matiri
# Processing Record 16 of Set 18 | zakharovo
# Processing Record 17 of Set 18 | thompson
# Processing Record 18 of Set 18 | alofi
# Processing Record 19 of Set 18 | green river
# Processing Record 20 of Set 18 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 18 | at-bashi
# Processing Record 22 of Set 18 | fortuna
# Processing Record 23 of Set 18 | georgetown
# Processing Record 24 of Set 18 | sandpoint
# Processing Record 25 of Set 18 | mayo
# Processing Record 26 of Set 18 | lagoa
# Processing Record 27 of Set 18 | port alfred
# Processing Record 28 of Set 18 | kudahuvadhoo
# Processing Record 29 of Set 18 | dublin
# Processing Record 30 of Set 18 | kalabo
# Processing Record 31 of Set 18 | ostrovnoy
# Processing Record 32 of Set 18 | lahad datu
# Processing Record 33 of Set 18 | dedougou
# Processing Record 34 of Set 18 | esperance
# Processing Record 35 of Set 18 | virginia beach
# Processing Record 36 of Set 18 | beyneu
# Processing Record 37 of Set 18 | michigan city
# Processing Record 38 of Set 18 | jalu
# Processing Record 39 of Set 18 | harper
# Processing Record 40 of Set 18 | gao
# Processing Record 41 of Set 18 | magrath
# Processing Record 42 of Set 18 | saint-joseph
# Processing Record 43 of Set 18 | vila franca do campo
# Processing Record 44 of Set 18 | sao filipe
# Processing Record 45 of Set 18 | karaman
# Processing Record 46 of Set 18 | elko
# Processing Record 47 of Set 18 | pochutla
# Processing Record 48 of Set 18 | pimenteiras
# Processing Record 49 of Set 18 | souillac
# Processing Record 50 of Set 18 | tunduru
# City not found. Skipping...
# Processing Record 1 of Set 19 | jinchang
# Processing Record 2 of Set 19 | chuy
# Processing Record 3 of Set 19 | kovur
# Processing Record 4 of Set 19 | toropets
# Processing Record 5 of Set 19 | caconda
# Processing Record 6 of Set 19 | cap malheureux
# Processing Record 7 of Set 19 | flinders
# Processing Record 8 of Set 19 | helong
# Processing Record 9 of Set 19 | oliver
# Processing Record 10 of Set 19 | gizo
# Processing Record 11 of Set 19 | chokurdakh
# Processing Record 12 of Set 19 | benghazi
# Processing Record 13 of Set 19 | whitehorse
# Processing Record 14 of Set 19 | henties bay
# Processing Record 15 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 19 | quang ngai
# Processing Record 17 of Set 19 | adre
# Processing Record 18 of Set 19 | lavrentiya
# Processing Record 19 of Set 19 | ruteng
# Processing Record 20 of Set 19 | port elizabeth
# Processing Record 21 of Set 19 | avarua
# Processing Record 22 of Set 19 | torbay
# Processing Record 23 of Set 19 | bambous virieux
# Processing Record 24 of Set 19 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 19 | ambilobe
# Processing Record 26 of Set 19 | naze
# Processing Record 27 of Set 19 | tiksi
# Processing Record 28 of Set 19 | milos
# Processing Record 29 of Set 19 | praia
# Processing Record 30 of Set 19 | nokaneng
# Processing Record 31 of Set 19 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 19 | balabac
# Processing Record 33 of Set 19 | umm lajj
# Processing Record 34 of Set 19 | sungaipenuh
# Processing Record 35 of Set 19 | tiarei
# Processing Record 36 of Set 19 | amaigbo
# Processing Record 37 of Set 19 | luwingu
# Processing Record 38 of Set 19 | pangnirtung
# Processing Record 39 of Set 19 | portland
# Processing Record 40 of Set 19 | aqtobe
# Processing Record 41 of Set 19 | chifeng
# Processing Record 42 of Set 19 | katsuura
# Processing Record 43 of Set 19 | waipawa
# Processing Record 44 of Set 19 | yuncheng
# Processing Record 45 of Set 19 | red bluff
# Processing Record 46 of Set 19 | ketchikan
# Processing Record 47 of Set 19 | mackay
# Processing Record 48 of Set 19 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 19 | jacareacanga
# Processing Record 50 of Set 19 | talara
# Processing Record 1 of Set 20 | gualeguay
# Processing Record 2 of Set 20 | husavik
# Processing Record 3 of Set 20 | ixtapa
# Processing Record 4 of Set 20 | manzil salim
# Processing Record 5 of Set 20 | comodoro rivadavia
# Processing Record 6 of Set 20 | isangel
# Processing Record 7 of Set 20 | chimbote
# Processing Record 8 of Set 20 | valparaiso
# Processing Record 9 of Set 20 | ivanteyevka
# Processing Record 10 of Set 20 | manokwari
# Processing Record 11 of Set 20 | morant bay
# Processing Record 12 of Set 20 | broome
# Processing Record 13 of Set 20 | hamilton
# Processing Record 14 of Set 20 | gummidipundi
# Processing Record 15 of Set 20 | victoria
# Processing Record 16 of Set 20 | mehamn
# Processing Record 17 of Set 20 | tomatlan
# Processing Record 18 of Set 20 | kosonsoy
# Processing Record 19 of Set 20 | fort nelson
# Processing Record 20 of Set 20 | saskylakh
# Processing Record 21 of Set 20 | evensk
# Processing Record 22 of Set 20 | mount isa
# Processing Record 23 of Set 20 | sumbawa
# City not found. Skipping...
# Processing Record 24 of Set 20 | yarim
# Processing Record 25 of Set 20 | kyra
# Processing Record 26 of Set 20 | ponta do sol
# Processing Record 27 of Set 20 | yar-sale
# Processing Record 28 of Set 20 | san vicente
# Processing Record 29 of Set 20 | camacari
# Processing Record 30 of Set 20 | kruisfontein
# Processing Record 31 of Set 20 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 20 | payo
# Processing Record 33 of Set 20 | conceicao do araguaia
# Processing Record 34 of Set 20 | rabwah
# City not found. Skipping...
# Processing Record 35 of Set 20 | gladstone
# Processing Record 36 of Set 20 | boundiali
# Processing Record 37 of Set 20 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 20 | severo-kurilsk
# Processing Record 39 of Set 20 | pampa
# Processing Record 40 of Set 20 | saint-pierre
# Processing Record 41 of Set 20 | togur
# Processing Record 42 of Set 20 | atambua
# Processing Record 43 of Set 20 | turayf
# Processing Record 44 of Set 20 | los llanos de aridane
# Processing Record 45 of Set 20 | salamiyah
# Processing Record 46 of Set 20 | porto empedocle
# Processing Record 47 of Set 20 | nantucket
# Processing Record 48 of Set 20 | casian
# Processing Record 49 of Set 20 | sibolga
# Processing Record 50 of Set 20 | tuatapere
# Processing Record 1 of Set 21 | stornoway
# Processing Record 2 of Set 21 | broken hill
# Processing Record 3 of Set 21 | dingle
# Processing Record 4 of Set 21 | labuhan
# Processing Record 5 of Set 21 | umba
# Processing Record 6 of Set 21 | rawson
# Processing Record 7 of Set 21 | ishimbay
# Processing Record 8 of Set 21 | grindavik
# Processing Record 9 of Set 21 | ndele
# Processing Record 10 of Set 21 | jiwani
# Processing Record 11 of Set 21 | vysokogornyy
# Processing Record 12 of Set 21 | mount gambier
# Processing Record 13 of Set 21 | wanning
# Processing Record 14 of Set 21 | kindu
# Processing Record 15 of Set 21 | buraydah
# Processing Record 16 of Set 21 | loikaw
# Processing Record 17 of Set 21 | shingu
# Processing Record 18 of Set 21 | alugan
# Processing Record 19 of Set 21 | la sarre
# Processing Record 20 of Set 21 | viedma
# Processing Record 21 of Set 21 | hami
# Processing Record 22 of Set 21 | batagay-alyta
# Processing Record 23 of Set 21 | coquimbo
# Processing Record 24 of Set 21 | bousso
# Processing Record 25 of Set 21 | douglas
# Processing Record 26 of Set 21 | choma
# Processing Record 27 of Set 21 | lorengau
# Processing Record 28 of Set 21 | palana
# Processing Record 29 of Set 21 | porto santo
# Processing Record 30 of Set 21 | salalah
# Processing Record 31 of Set 21 | vicksburg
# Processing Record 32 of Set 21 | sitka
# Processing Record 33 of Set 21 | sandur
# Processing Record 34 of Set 21 | winslow
# Processing Record 35 of Set 21 | redlands
# Processing Record 36 of Set 21 | mantua
# Processing Record 37 of Set 21 | kpalime
# Processing Record 38 of Set 21 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 21 | taoudenni
# Processing Record 40 of Set 21 | nanga eboko
# Processing Record 41 of Set 21 | lima
# Processing Record 42 of Set 21 | molde
# Processing Record 43 of Set 21 | nome
# Processing Record 44 of Set 21 | krutinka
# Processing Record 45 of Set 21 | azangaro
# Processing Record 46 of Set 21 | sibu
# Processing Record 47 of Set 21 | tumannyy
# City not found. Skipping...
# Processing Record 48 of Set 21 | marquette
# Processing Record 49 of Set 21 | south venice
# Processing Record 50 of Set 21 | hunza
# City not found. Skipping...
# Processing Record 1 of Set 22 | maldonado
# Processing Record 2 of Set 22 | mankachar
# Processing Record 3 of Set 22 | port-de-bouc
# Processing Record 4 of Set 22 | salamanca
# Processing Record 5 of Set 22 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 22 | naujoji akmene
# Processing Record 7 of Set 22 | savinka
# Processing Record 8 of Set 22 | kiunga
# Processing Record 9 of Set 22 | lake havasu city
# Processing Record 10 of Set 22 | hobyo
# Processing Record 11 of Set 22 | sayyan
# Processing Record 12 of Set 22 | ekhabi
# Processing Record 13 of Set 22 | pimentel
# Processing Record 14 of Set 22 | palmer
# Processing Record 15 of Set 22 | aswan
# Processing Record 16 of Set 22 | sola
# Processing Record 17 of Set 22 | jutai
# Processing Record 18 of Set 22 | faya
# Processing Record 19 of Set 22 | shahdadpur
# Processing Record 20 of Set 22 | horsham
# Processing Record 21 of Set 22 | marathon
# Processing Record 22 of Set 22 | krasnoarmeyskiy
# Processing Record 23 of Set 22 | kahama
# Processing Record 24 of Set 22 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 22 | andevoranto
# City not found. Skipping...
# Processing Record 26 of Set 22 | warqla
# City not found. Skipping...
# Processing Record 27 of Set 22 | avera
# Processing Record 28 of Set 22 | ilo
# Processing Record 29 of Set 22 | honiara
# Processing Record 30 of Set 22 | paamiut
# Processing Record 31 of Set 22 | wanaka
# Processing Record 32 of Set 22 | saint anthony
# Processing Record 33 of Set 22 | nanortalik
# Processing Record 34 of Set 22 | prince rupert
# Processing Record 35 of Set 22 | shache
# Processing Record 36 of Set 22 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 22 | san luis
# Processing Record 38 of Set 22 | richards bay
# Processing Record 39 of Set 22 | narsaq
# Processing Record 40 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 22 | san cristobal
# Processing Record 42 of Set 22 | payson
# Processing Record 43 of Set 22 | ulladulla
# Processing Record 44 of Set 22 | nishihara
# Processing Record 45 of Set 22 | grand gaube
# Processing Record 46 of Set 22 | wulanhaote
# City not found. Skipping...
# Processing Record 47 of Set 22 | meadow lake
# Processing Record 48 of Set 22 | altamira
# Processing Record 49 of Set 22 | umm durman
# City not found. Skipping...
# Processing Record 50 of Set 22 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 23 | cazaje
# City not found. Skipping...
# Processing Record 2 of Set 23 | curanilahue
# Processing Record 3 of Set 23 | arman
# Processing Record 4 of Set 23 | bilma
# Processing Record 5 of Set 23 | ust-kuyga
# Processing Record 6 of Set 23 | aklavik
# Processing Record 7 of Set 23 | umm ruwabah
# City not found. Skipping...
# Processing Record 8 of Set 23 | banjarmasin
# Processing Record 9 of Set 23 | wajir
# Processing Record 10 of Set 23 | aripuana
# Processing Record 11 of Set 23 | inhambane
# Processing Record 12 of Set 23 | biabou
# Processing Record 13 of Set 23 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 23 | huambo
# Processing Record 15 of Set 23 | bealanana
# Processing Record 16 of Set 23 | bardiyah
# Processing Record 17 of Set 23 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 23 | dakoro
# Processing Record 19 of Set 23 | san juan
# Processing Record 20 of Set 23 | hammerfest
# Processing Record 21 of Set 23 | egvekinot
# Processing Record 22 of Set 23 | kokopo
# Processing Record 23 of Set 23 | omboue
# Processing Record 24 of Set 23 | praxedis guerrero
# Processing Record 25 of Set 23 | jiangyou
# Processing Record 26 of Set 23 | xai-xai
# Processing Record 27 of Set 23 | vila velha
# Processing Record 28 of Set 23 | cabedelo
# Processing Record 29 of Set 23 | sao jose da laje
# Processing Record 30 of Set 23 | luganville
# Processing Record 31 of Set 23 | mbalmayo
# Processing Record 32 of Set 23 | kangaatsiaq
# Processing Record 33 of Set 23 | flin flon
# Processing Record 34 of Set 23 | chicama
# Processing Record 35 of Set 23 | anan
# Processing Record 36 of Set 23 | niamtougou
# Processing Record 37 of Set 23 | mahibadhoo
# Processing Record 38 of Set 23 | gravdal
# Processing Record 39 of Set 23 | ancud
# Processing Record 40 of Set 23 | uyuni
# Processing Record 41 of Set 23 | onega
# Processing Record 42 of Set 23 | canby
# Processing Record 43 of Set 23 | the valley
# Processing Record 44 of Set 23 | oranjestad
# Processing Record 45 of Set 23 | khani
# Processing Record 46 of Set 23 | khanpur
# Processing Record 47 of Set 23 | la asuncion
# Processing Record 48 of Set 23 | mattru
# Processing Record 49 of Set 23 | pravia
# Processing Record 50 of Set 23 | rio gallegos
# Processing Record 1 of Set 24 | pisco
# Processing Record 2 of Set 24 | yoichi
# Processing Record 3 of Set 24 | kathmandu
# Processing Record 4 of Set 24 | stokmarknes
# Processing Record 5 of Set 24 | rocha
# Processing Record 6 of Set 24 | zhigansk
# Processing Record 7 of Set 24 | omama
# Processing Record 8 of Set 24 | basoko
# Processing Record 9 of Set 24 | skalistyy
# City not found. Skipping...
# Processing Record 10 of Set 24 | koson
# Processing Record 11 of Set 24 | nichinan
# Processing Record 12 of Set 24 | kurumkan
# Processing Record 13 of Set 24 | tura
# Processing Record 14 of Set 24 | nizhniy tsasuchey
# Processing Record 15 of Set 24 | nazarovo
# Processing Record 16 of Set 24 | namalenga
# Processing Record 17 of Set 24 | houlung
# City not found. Skipping...
# Processing Record 18 of Set 24 | ballina
# Processing Record 19 of Set 24 | constitucion
# Processing Record 20 of Set 24 | ruhengeri
# Processing Record 21 of Set 24 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 24 | mana
# Processing Record 23 of Set 24 | nagato
# Processing Record 24 of Set 24 | srivardhan
# Processing Record 25 of Set 24 | pokhara
# Processing Record 26 of Set 24 | mahon
# Processing Record 27 of Set 24 | srednekolymsk
# Processing Record 28 of Set 24 | statesville
# Processing Record 29 of Set 24 | bengkulu
# Processing Record 30 of Set 24 | nanchong
# Processing Record 31 of Set 24 | san juan evangelista
# Processing Record 32 of Set 24 | college
# Processing Record 33 of Set 24 | wad madani
# Processing Record 34 of Set 24 | barkly west
# Processing Record 35 of Set 24 | qaqortoq
# Processing Record 36 of Set 24 | duz
# City not found. Skipping...
# Processing Record 37 of Set 24 | coahuayana
# Processing Record 38 of Set 24 | mogadishu
# Processing Record 39 of Set 24 | nipawin
# Processing Record 40 of Set 24 | ponta delgada
# Processing Record 41 of Set 24 | aksay
# Processing Record 42 of Set 24 | sampit
# Processing Record 43 of Set 24 | zhezkazgan
# Processing Record 44 of Set 24 | porto novo
# Processing Record 45 of Set 24 | meyungs
# City not found. Skipping...
# Processing Record 46 of Set 24 | atbasar
# Processing Record 47 of Set 24 | amapa
# Processing Record 48 of Set 24 | dawson creek
# Processing Record 49 of Set 24 | afmadu
# City not found. Skipping...
# Processing Record 50 of Set 24 | tessalit
# Processing Record 1 of Set 25 | rapid valley
# Processing Record 2 of Set 25 | sauk rapids
# Processing Record 3 of Set 25 | iracoubo
# Processing Record 4 of Set 25 | suluq
# Processing Record 5 of Set 25 | ornskoldsvik
# Processing Record 6 of Set 25 | zalantun
# Processing Record 7 of Set 25 | chauk
# Processing Record 8 of Set 25 | kirakira
# Processing Record 9 of Set 25 | alexandria
# Processing Record 10 of Set 25 | cayenne
# Processing Record 11 of Set 25 | westpunt
# City not found. Skipping...
# Processing Record 12 of Set 25 | daru
# Processing Record 13 of Set 25 | ampanihy
# Processing Record 14 of Set 25 | pachelma
# Processing Record 15 of Set 25 | langsa
# Processing Record 16 of Set 25 | namibe
# Processing Record 17 of Set 25 | luena
# Processing Record 18 of Set 25 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 25 | sechura
# Processing Record 20 of Set 25 | lac du bonnet
# Processing Record 21 of Set 25 | luanda
# Processing Record 22 of Set 25 | makokou
# Processing Record 23 of Set 25 | saquarema
# Processing Record 24 of Set 25 | armidale
# Processing Record 25 of Set 25 | vostok
# Processing Record 26 of Set 25 | atar
# Processing Record 27 of Set 25 | samarinda
# Processing Record 28 of Set 25 | maracas
# Processing Record 29 of Set 25 | soyo
# Processing Record 30 of Set 25 | itaituba
# Processing Record 31 of Set 25 | naral
# City not found. Skipping...
# Processing Record 32 of Set 25 | vernon
# Processing Record 33 of Set 25 | yinchuan
# Processing Record 34 of Set 25 | yvetot
# Processing Record 35 of Set 25 | boulsa
# Processing Record 36 of Set 25 | mullaitivu
# City not found. Skipping...
# Processing Record 37 of Set 25 | talisayan
# Processing Record 38 of Set 25 | ambagarh chauki
# Processing Record 39 of Set 25 | santa cruz
# Processing Record 40 of Set 25 | bereda
# Processing Record 41 of Set 25 | manakara
# Processing Record 42 of Set 25 | poum
# Processing Record 43 of Set 25 | marsh harbour
# Processing Record 44 of Set 25 | quatre cocos
# Processing Record 45 of Set 25 | cave spring
# Processing Record 46 of Set 25 | sakakah
# Processing Record 47 of Set 25 | maragogi
# Processing Record 48 of Set 25 | bainbridge
# Processing Record 49 of Set 25 | chapais
# Processing Record 50 of Set 25 | vestmanna
# Processing Record 1 of Set 26 | freeport
# Processing Record 2 of Set 26 | silifke
# Processing Record 3 of Set 26 | talant
# Processing Record 4 of Set 26 | garden city
# Processing Record 5 of Set 26 | north platte
# Processing Record 6 of Set 26 | praya
# Processing Record 7 of Set 26 | sao francisco do sul
# Processing Record 8 of Set 26 | okhotsk
# Processing Record 9 of Set 26 | la ronge
# Processing Record 10 of Set 26 | seddon
# Processing Record 11 of Set 26 | otradnoye
# Processing Record 12 of Set 26 | maniitsoq
# Processing Record 13 of Set 26 | conde
# Processing Record 14 of Set 26 | san ramon de la nueva oran
# Processing Record 15 of Set 26 | aranos
# Processing Record 16 of Set 26 | gobabis
# Processing Record 17 of Set 26 | holoby
# Processing Record 18 of Set 26 | maun
# Processing Record 19 of Set 26 | tubruq
# City not found. Skipping...
# Processing Record 20 of Set 26 | menongue
# Processing Record 21 of Set 26 | antalaha
# Processing Record 22 of Set 26 | punta alta
# Processing Record 23 of Set 26 | dolinsk
# Processing Record 24 of Set 26 | fort-shevchenko
# Processing Record 25 of Set 26 | olinda
# Processing Record 26 of Set 26 | mieres
# Processing Record 27 of Set 26 | troitskoye
# Processing Record 28 of Set 26 | mariental
# Processing Record 29 of Set 26 | walvis bay
# Processing Record 30 of Set 26 | pipar
# Processing Record 31 of Set 26 | polunochnoye
# Processing Record 32 of Set 26 | parrita
# Processing Record 33 of Set 26 | bayan
# Processing Record 34 of Set 26 | kinna
# Processing Record 35 of Set 26 | drovyanaya
# Processing Record 36 of Set 26 | exeter
# Processing Record 37 of Set 26 | springbok
# Processing Record 38 of Set 26 | jiazi
# Processing Record 39 of Set 26 | raga
# Processing Record 40 of Set 26 | puerto madryn
# Processing Record 41 of Set 26 | batemans bay
# Processing Record 42 of Set 26 | isfana
# Processing Record 43 of Set 26 | council bluffs
# Processing Record 44 of Set 26 | lamar
# Processing Record 45 of Set 26 | cedar park
# Processing Record 46 of Set 26 | meulaboh
# Processing Record 47 of Set 26 | port hardy
# Processing Record 48 of Set 26 | itarema
# Processing Record 49 of Set 26 | novikovo
# Processing Record 50 of Set 26 | honolulu
# Processing Record 1 of Set 27 | gasa
# Processing Record 2 of Set 27 | sao borja
# Processing Record 3 of Set 27 | stepnoye
# Processing Record 4 of Set 27 | tonk
# Processing Record 5 of Set 27 | muros
# Processing Record 6 of Set 27 | falun
# Processing Record 7 of Set 27 | yulara
# Processing Record 8 of Set 27 | aue
# Processing Record 9 of Set 27 | vulcan
# Processing Record 10 of Set 27 | ahuimanu
# Processing Record 11 of Set 27 | flic en flac
# Processing Record 12 of Set 27 | little current
# Processing Record 13 of Set 27 | tokonou
# Processing Record 14 of Set 27 | talnakh
# Processing Record 15 of Set 27 | nouadhibou
# Processing Record 16 of Set 27 | kalga
# Processing Record 17 of Set 27 | hofn
# Processing Record 18 of Set 27 | kuah
# Processing Record 19 of Set 27 | acapulco
# Processing Record 20 of Set 27 | saint-leu
# Processing Record 21 of Set 27 | oranjemund
# Processing Record 22 of Set 27 | dabakala
# Processing Record 23 of Set 27 | sousa
# Processing Record 24 of Set 27 | minab
# Processing Record 25 of Set 27 | ratnagiri
# Processing Record 26 of Set 27 | piranshahr
# Processing Record 27 of Set 27 | abha
# Processing Record 28 of Set 27 | letka
# Processing Record 29 of Set 27 | mabaruma
# Processing Record 30 of Set 27 | kendari
# Processing Record 31 of Set 27 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 27 | high level
# Processing Record 33 of Set 27 | lasa
# Processing Record 34 of Set 27 | nautla
# Processing Record 35 of Set 27 | loutros
# Processing Record 36 of Set 27 | lahaina
# Processing Record 37 of Set 27 | bangkalan
# Processing Record 38 of Set 27 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 27 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 27 | guajara-mirim
# City not found. Skipping...
# Processing Record 41 of Set 27 | gwembe
# Processing Record 42 of Set 27 | chinhoyi
# Processing Record 43 of Set 27 | tornio
# Processing Record 44 of Set 27 | udachnyy
# Processing Record 45 of Set 27 | manggar
# Processing Record 46 of Set 27 | felidhoo
# City not found. Skipping...
# Processing Record 47 of Set 27 | bud
# Processing Record 48 of Set 27 | byron bay
# Processing Record 49 of Set 27 | ilebo
# Processing Record 50 of Set 27 | gazli
# Processing Record 1 of Set 28 | tambacounda
# Processing Record 2 of Set 28 | cotonou
# Processing Record 3 of Set 28 | quelimane
# Processing Record 4 of Set 28 | ipixuna
# Processing Record 5 of Set 28 | kununurra
# Processing Record 6 of Set 28 | san patricio
# Processing Record 7 of Set 28 | suihua
# Processing Record 8 of Set 28 | tapaua
# City not found. Skipping...
# Processing Record 9 of Set 28 | kidal
# Processing Record 10 of Set 28 | golden
# Processing Record 11 of Set 28 | orlik
# Processing Record 12 of Set 28 | sturgeon bay
# Processing Record 13 of Set 28 | loknya
# Processing Record 14 of Set 28 | bisira
# Processing Record 15 of Set 28 | nam tha
# City not found. Skipping...
# Processing Record 16 of Set 28 | marrakesh
# Processing Record 17 of Set 28 | tsumeb
# Processing Record 18 of Set 28 | necochea
# Processing Record 19 of Set 28 | hutchinson
# Processing Record 20 of Set 28 | okandja
# City not found. Skipping...
# Processing Record 21 of Set 28 | kushmurun
# Processing Record 22 of Set 28 | shawnee
# Processing Record 23 of Set 28 | puerto escondido
# Processing Record 24 of Set 28 | lamu
# Processing Record 25 of Set 28 | dhidhdhoo
# Processing Record 26 of Set 28 | yamada
# Processing Record 27 of Set 28 | santa maria
# Processing Record 28 of Set 28 | iquique
# Processing Record 29 of Set 28 | matara
# Processing Record 30 of Set 28 | bassano
# Processing Record 31 of Set 28 | antofagasta
# Processing Record 32 of Set 28 | kentau
# Processing Record 33 of Set 28 | cockburn town
# Processing Record 34 of Set 28 | turukhansk
# Processing Record 35 of Set 28 | batatais
# Processing Record 36 of Set 28 | baragua
# Processing Record 37 of Set 28 | grimmen
# Processing Record 38 of Set 28 | lata
# Processing Record 39 of Set 28 | mhlambanyatsi
# Processing Record 40 of Set 28 | mbacke
# City not found. Skipping...
# Processing Record 41 of Set 28 | warrington
# Processing Record 42 of Set 28 | lewistown
# Processing Record 43 of Set 28 | sena madureira
# Processing Record 44 of Set 28 | mareeba
# Processing Record 45 of Set 28 | longyan
# Processing Record 46 of Set 28 | wajima
# Processing Record 47 of Set 28 | oktyabrskiy
# Processing Record 48 of Set 28 | dalby
# Processing Record 49 of Set 28 | methoni
# Processing Record 50 of Set 28 | san ignacio
# Processing Record 1 of Set 29 | vuktyl
# Processing Record 2 of Set 29 | beringovskiy
# Processing Record 3 of Set 29 | bornem
# Processing Record 4 of Set 29 | camalu
# Processing Record 5 of Set 29 | linkou
# Processing Record 6 of Set 29 | chute-aux-outardes
# Processing Record 7 of Set 29 | jizan
# Processing Record 8 of Set 29 | christchurch
# Processing Record 9 of Set 29 | nagapattinam
# Processing Record 10 of Set 29 | vardo
# Processing Record 11 of Set 29 | cabo san lucas
# Processing Record 12 of Set 29 | bilibino
# Processing Record 13 of Set 29 | roald
# Processing Record 14 of Set 29 | champerico
# Processing Record 15 of Set 29 | winneba
# Processing Record 16 of Set 29 | uusikaupunki
# Processing Record 17 of Set 29 | kutum
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City      Lat       Lng Current Description  Max Temp  Humidity  \
# 0    East London -33.0153   27.9116       broken clouds     64.67        71
# 1      Geraldton -28.7667  114.6000       broken clouds     55.81        94
# 2           Biak  -0.9131  122.8766     overcast clouds     76.55        87
# 3          Vaini -21.2000 -175.2000          few clouds     71.76        68
# 4  Murray Bridge -35.1167  139.2667           clear sky     62.13        90
#
#    Cloudiness  Wind Speed Country
# 0          51       11.05      ZA
# 1          68       10.36      AU
# 2         100        3.85      ID
# 3          20        8.05      TO
# 4           0        7.36      AU

# %%
new_city_data_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df.reindex(columns=new_city_data_df)

# %%
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    East London      ZA -33.0153   27.9116     64.67        71          51
# 1      Geraldton      AU -28.7667  114.6000     55.81        94          68
# 2           Biak      ID  -0.9131  122.8766     76.55        87         100
# 3          Vaini      TO -21.2000 -175.2000     71.76        68          20
# 4  Murray Bridge      AU -35.1167  139.2667     62.13        90           0
# 5   Longyearbyen      SJ  78.2186   15.6401     30.04        64          75
# 6        Rikitea      PF -23.1203 -134.9692     76.30        68           0
# 7         Taltal      CL -25.4000  -70.4833     65.46        66           0
# 8       Yantzaza      EC  -3.8278  -78.7594     77.79        75          95
# 9  Sioux Lookout      CA  50.1001  -91.9170     67.95        38           6
#
#    Wind Speed Current Description
# 0       11.05       broken clouds
# 1       10.36       broken clouds
# 2        3.85     overcast clouds
# 3        8.05          few clouds
# 4        7.36           clear sky
# 5        3.44       broken clouds
# 6       23.64           clear sky
# 7        6.17           clear sky
# 8        2.30          light rain
# 9       12.55       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# %%
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)
